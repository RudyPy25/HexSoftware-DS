# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as py

# %%
data = pd.read_csv("E:\\spotify dataset\\Spotify.csv")

# %%
#1 understanding the data

# %%
data.head()
# Out:
#    Index                   Title             Artist            Top Genre  \
# 0      1                 Sunrise        Norah Jones      adult standards
# 1      2             Black Night        Deep Purple           album rock
# 2      3          Clint Eastwood           Gorillaz  alternative hip hop
# 3      4           The Pretender       Foo Fighters    alternative metal
# 4      5  Waitin' On A Sunny Day  Bruce Springsteen         classic rock
#
#    Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 0  2004                     157      30            53            -14
# 1  2000                     135      79            50            -11
# 2  2001                     168      69            66             -9
# 3  2007                     173      96            43             -4
# 4  2002                     106      82            58             -5
#
#    Liveness  Valence Length (Duration)  Acousticness  Speechiness  Popularity
# ...

# %%
data.tail()
# Out:
#       Index             Title                    Artist        Top Genre  \
# 1989   1990  Heartbreak Hotel             Elvis Presley  adult standards
# 1990   1991         Hound Dog             Elvis Presley  adult standards
# 1991   1992   Johnny B. Goode               Chuck Berry       blues rock
# 1992   1993         Take Five  The Dave Brubeck Quartet            bebop
# 1993   1994    Blueberry Hill               Fats Domino  adult standards
#
#       Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 1989  1958                      94      21            70            -12
# 1990  1958                     175      76            36             -8
# 1991  1959                     168      80            53             -9
# 1992  1959                     174      26            45            -13
# 1993  1959                     133      50            49            -10
#
#       Liveness  Valence Length (Duration)  Acousticness  Speechiness  \
# ...

# %%
data.shape
# Out:
# (1994, 15)

# %%
data.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)       Energy  \
# count  1994.000000  1994.000000             1994.000000  1994.000000
# mean    997.500000  1992.992979              120.215647    59.679539
# std     575.762538    16.116048               28.028096    22.154322
# min       1.000000  1956.000000               37.000000     3.000000
# 25%     499.250000  1979.000000               99.000000    42.000000
# 50%     997.500000  1993.000000              119.000000    61.000000
# 75%    1495.750000  2007.000000              136.000000    78.000000
# max    1994.000000  2019.000000              206.000000   100.000000
#
#        Danceability  Loudness (dB)     Liveness      Valence  Acousticness  \
# count   1994.000000    1994.000000  1994.000000  1994.000000   1994.000000
# mean      53.238215      -9.008526    19.012036    49.408726     28.858074
# std       15.351507       3.647876    16.727378    24.858212     29.011986
# ...

# %%
data.columns
# Out:
# Index(['Index', 'Title', 'Artist', 'Top Genre', 'Year',
#        'Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
#        'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
#        'Speechiness', 'Popularity'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Index                     1994
# Title                     1958
# Artist                     731
# Top Genre                  149
# Year                        63
# Beats Per Minute (BPM)     145
# Energy                      98
# Danceability                84
# Loudness (dB)               23
# Liveness                    94
# Valence                     97
# Length (Duration)          350
# Acousticness               100
# Speechiness                 37
# Popularity                  81
# dtype: int64

# %%
data['Index'].unique()
# Out:
# array([   1,    2,    3, ..., 1992, 1993, 1994])

# %%
data['Title'].unique()
# Out:
# array(['Sunrise', 'Black Night', 'Clint Eastwood', ..., 'Johnny B. Goode',
#        'Take Five', 'Blueberry Hill'], dtype=object)

# %%
#2 cleaning the data

# %%
data.isnull().sum()
# Out:
# Index                     0
# Title                     0
# Artist                    0
# Top Genre                 0
# Year                      0
# Beats Per Minute (BPM)    0
# Energy                    0
# Danceability              0
# Loudness (dB)             0
# Liveness                  0
# Valence                   0
# Length (Duration)         0
# Acousticness              0
# Speechiness               0
# Popularity                0
# dtype: int64

# %%
spotify = data.drop(['Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)', 'Liveness', 'Valence', 'Length (Duration)', 'Title'], axis=1)

# %%
spotify.head()
# Out:
#    Index             Artist            Top Genre  Year  Acousticness  \
# 0      1        Norah Jones      adult standards  2004            94
# 1      2        Deep Purple           album rock  2000            17
# 2      3           Gorillaz  alternative hip hop  2001             2
# 3      4       Foo Fighters    alternative metal  2007             0
# 4      5  Bruce Springsteen         classic rock  2002             1
#
#    Speechiness  Popularity
# 0            3          71
# 1            7          39
# 2           17          69
# 3            4          76
# 4            3          59

# %%
#3 relationship analysis

# %%
print(spotify.dtypes)
# Out:
# Index            int64
# Artist          object
# Top Genre       object
# Year             int64
# Acousticness     int64
# Speechiness      int64
# Popularity       int64
# dtype: object

# %%
numeric_columns = spotify.select_dtypes(include=[float, int])
# Step 1: Select only numeric columns

# %%
# Step 2: Compute correlation on the numeric subset of the DataFrame
correlation = numeric_columns.corr()

# %%
print(correlation)
# Out:
#                  Index      Year  Acousticness  Speechiness  Popularity
# Index         1.000000 -0.607910      0.057346    -0.050991    0.087442
# Year         -0.607910  1.000000     -0.132946     0.054097   -0.158962
# Acousticness  0.057346 -0.132946      1.000000    -0.098256   -0.087604
# Speechiness  -0.050991  0.054097     -0.098256     1.000000    0.111689
# Popularity    0.087442 -0.158962     -0.087604     0.111689    1.000000

# %%
# Attempt to convert all columns to numeric, forcing non-convertible entries to NaN
spotify_numeric = spotify.apply(pd.to_numeric, errors='coerce')

# Compute correlation on the numeric DataFrame
correlation = spotify_numeric.corr()

print(correlation)
# Out:
#                  Index  Artist  Top Genre      Year  Acousticness  \
# Index         1.000000     NaN        NaN -0.607910      0.057346
# Artist             NaN     NaN        NaN       NaN           NaN
# Top Genre          NaN     NaN        NaN       NaN           NaN
# Year         -0.607910     NaN        NaN  1.000000     -0.132946
# Acousticness  0.057346     NaN        NaN -0.132946      1.000000
# Speechiness  -0.050991     NaN        NaN  0.054097     -0.098256
# Popularity    0.087442     NaN        NaN -0.158962     -0.087604
#
#               Speechiness  Popularity
# Index           -0.050991    0.087442
# Artist                NaN         NaN
# Top Genre             NaN         NaN
# Year             0.054097   -0.158962
# Acousticness    -0.098256   -0.087604
# Speechiness      1.000000    0.111689
# Popularity       0.111689    1.000000

# %%
correlation = spotify_numeric.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(spotify_numeric)

# %%
sns.relplot(x='Year', y='Acousticness', hue='Speechiness', data=spotify_numeric)

# %%
sns.distplot(spotify_numeric['Year'], bins=10)
# Out:
# C:\Users\Rudy\AppData\Local\Temp\ipykernel_2400\2706168287.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(spotify_numeric['Year'], bins=10)
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.catplot(x='Year', kind='box', data=spotify_numeric)
